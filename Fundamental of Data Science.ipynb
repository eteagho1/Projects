# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Importig the various libraries

# %%
df=pd.read_csv('census02.csv')
# reading the census02 dataset

# %%
df
# calling the dataset
# Out:
#        House Number         Street First Name    Surname   Age  \
# 0                 1     Kaur Drive    Douglas      Adams  77.0
# 1                 2     Kaur Drive     Hollie       West  79.0
# 2                 3     Kaur Drive     Joseph       Hall  55.0
# 3                 4     Kaur Drive    Gregory        Cox  35.0
# 4                 5     Kaur Drive      Lydia      Jones  42.0
# ...             ...            ...        ...        ...   ...
# 10113             1  St.John Haven    Patrick     Morgan   9.0
# 10114             1  St.John Haven   Caroline     Morgan   6.0
# 10115             1  St.John Haven   Benjamin     Morgan   2.0
# 10116             1  St.John Haven       Kate  Whitehead  51.0
# 10117             1  St.John Haven    Abigail      Brown  47.0
#
#       Relationship to Head of House Marital Status  Gender  \
# 0                              Head        Widowed    Male
# 1                              Head         Single  Female
# ...

# %%
df.head()
# reading the first five rows using the head method
# Out:
#    House Number      Street First Name Surname   Age  \
# 0             1  Kaur Drive    Douglas   Adams  77.0
# 1             2  Kaur Drive     Hollie    West  79.0
# 2             3  Kaur Drive     Joseph    Hall  55.0
# 3             4  Kaur Drive    Gregory     Cox  35.0
# 4             5  Kaur Drive      Lydia   Jones  42.0
#
#   Relationship to Head of House Marital Status  Gender  \
# 0                          Head        Widowed    Male
# 1                          Head         Single  Female
# 2                          Head         Single    Male
# 3                          Head         Single    Male
# 4                          Head         Single  Female
#
#                          Occupation Infirmity   Religion
# 0  Retired Museum education officer      None  Christian
# 1                    Retired Dealer      None  Christian
# 2      Fast food restaurant manager      None  Christian
# 3           Housing manager/officer      None       None
# ...

# %%
df.columns
# reading the columns
# Out:
# Index(['House Number', 'Street', 'First Name', 'Surname', 'Age',
#        'Relationship to Head of House', 'Marital Status', 'Gender',
#        'Occupation', 'Infirmity', 'Religion'],
#       dtype='object')

# %%
df.tail()
# reading the last 5 rows using the tail method
# Out:
#        House Number         Street First Name    Surname   Age  \
# 10113             1  St.John Haven    Patrick     Morgan   9.0
# 10114             1  St.John Haven   Caroline     Morgan   6.0
# 10115             1  St.John Haven   Benjamin     Morgan   2.0
# 10116             1  St.John Haven       Kate  Whitehead  51.0
# 10117             1  St.John Haven    Abigail      Brown  47.0
#
#       Relationship to Head of House Marital Status  Gender         Occupation  \
# 10113                           Son            NaN    Male            Student
# 10114                      Daughter            NaN  Female            Student
# 10115                           Son            NaN    Male              Child
# 10116                       Sibling         Single  Female  Food technologist
# 10117                        Lodger         Single  Female       Web designer
#
#       Infirmity   Religion
# 10113      None        NaN
# 10114      None        NaN
# 10115      None        NaN
# ...

# %%
df.shape
# looking out for the total number of rows and column
# Out:
# (10118, 11)

# %%
df.isnull().sum()
# looking out for null values
# Out:
# House Number                        0
# Street                              0
# First Name                          0
# Surname                             0
# Age                                 0
# Relationship to Head of House       0
# Marital Status                   2484
# Gender                              0
# Occupation                          0
# Infirmity                           0
# Religion                         2541
# dtype: int64

# %%
df['Marital Status'].fillna('Single',inplace=True)
# filling the nan values with Single in the marital status column

# %%
df
# reading the dataset
# Out:
#        House Number         Street First Name    Surname   Age  \
# 0                 1     Kaur Drive    Douglas      Adams  77.0
# 1                 2     Kaur Drive     Hollie       West  79.0
# 2                 3     Kaur Drive     Joseph       Hall  55.0
# 3                 4     Kaur Drive    Gregory        Cox  35.0
# 4                 5     Kaur Drive      Lydia      Jones  42.0
# ...             ...            ...        ...        ...   ...
# 10113             1  St.John Haven    Patrick     Morgan   9.0
# 10114             1  St.John Haven   Caroline     Morgan   6.0
# 10115             1  St.John Haven   Benjamin     Morgan   2.0
# 10116             1  St.John Haven       Kate  Whitehead  51.0
# 10117             1  St.John Haven    Abigail      Brown  47.0
#
#       Relationship to Head of House Marital Status  Gender  \
# 0                              Head        Widowed    Male
# 1                              Head         Single  Female
# ...

# %%
df['Religion'].fillna('Christian',inplace=True)
# filling the nan values in the Religion column

# %%
df
# read the dataset
# Out:
#        House Number         Street First Name    Surname   Age  \
# 0                 1     Kaur Drive    Douglas      Adams  77.0
# 1                 2     Kaur Drive     Hollie       West  79.0
# 2                 3     Kaur Drive     Joseph       Hall  55.0
# 3                 4     Kaur Drive    Gregory        Cox  35.0
# 4                 5     Kaur Drive      Lydia      Jones  42.0
# ...             ...            ...        ...        ...   ...
# 10113             1  St.John Haven    Patrick     Morgan   9.0
# 10114             1  St.John Haven   Caroline     Morgan   6.0
# 10115             1  St.John Haven   Benjamin     Morgan   2.0
# 10116             1  St.John Haven       Kate  Whitehead  51.0
# 10117             1  St.John Haven    Abigail      Brown  47.0
#
#       Relationship to Head of House Marital Status  Gender  \
# 0                              Head        Widowed    Male
# 1                              Head         Single  Female
# ...

# %%
df.describe()
# reading the statistical values of the dataset
# Out:
#        House Number           Age
# count  10118.000000  10118.000000
# mean      44.312908     35.163123
# std       48.718713     21.382406
# min        1.000000      0.000000
# 25%       11.000000     18.000000
# 50%       25.000000     34.000000
# 75%       56.000000     50.000000
# max      208.000000    120.000000

# %%
df.count()
# counting the total number of rows and columns
# Out:
# House Number                     10118
# Street                           10118
# First Name                       10118
# Surname                          10118
# Age                              10118
# Relationship to Head of House    10118
# Marital Status                   10118
# Gender                           10118
# Occupation                       10118
# Infirmity                        10118
# Religion                         10118
# dtype: int64

# %%
df.shape
# Out:
# (10118, 11)

# %%
x=df['Age']
y=df['Marital Status']
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Marital Status')
plt.barh(x,y)
plt.show()
# plotting a horizontal bar chart for Age against Marital Status

# %%
plt.boxplot(df['Age'])
# Plotting a boxplot for Age
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2289f9e97d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2289d26fa90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2289cb401d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x228a198bf90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x228a198ad10>],
#  'means': []}

# %%
plt.hist(df['Marital Status'],color='red')
plt.show()
# Plotting a histogram for Marital Status

# %%
sns.displot(df['Age'],bins=20,kde=True)

# %%
sns.heatmap(df)
